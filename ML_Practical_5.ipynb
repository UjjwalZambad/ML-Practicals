# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Ujjwal\Desktop\Market_Basket_Optimisation.csv", header=None)

# %%
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
transacts = []
for i in range(0, 7501):
    
     transacts.append([str(df.values[i,j]) for j in range(0,20)])

# %%
from apyori import apriori
rule = apriori(transactions = transacts, min_support = 0.003, min_confidence=0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
output=list(rule)

# %%
output_DataFrame = pd.DataFrame([(tuple(result.items)[0], tuple(result.items)[1],result.support,result.ordered_statistics[0].confidence,result.ordered_statistics[0].lift) for result in output],
                               columns=['Antecedent','Consequent','Support','Confidence','Lift'])`

# %%
output_DataFrame
# Out:
#           Antecedent            Consequent   Support  Confidence      Lift
# 0        light cream               chicken  0.004533    0.290598  4.843951
# 1           escalope  mushroom cream sauce  0.005733    0.300699  3.790833
# 2           escalope                 pasta  0.005866    0.372881  4.700812
# 3              honey         fromage blanc  0.003333    0.245098  5.164271
# 4      herb & pepper           ground beef  0.015998    0.323450  3.291994
# 5        ground beef          tomato sauce  0.005333    0.377358  3.840659
# 6        light cream             olive oil  0.003200    0.205128  3.114710
# 7  whole wheat pasta             olive oil  0.007999    0.271493  4.122410
# 8             shrimp                 pasta  0.005066    0.322034  4.506672
